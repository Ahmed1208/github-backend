# %%
from database_module import *
from similarity_model_module import *

# %% [markdown]
# #### Note --> user must change paths, images path saved in db is:  ' 101_ObjectCategories/airplanes/image_0001.jpg '

# %%
images_foler_path = 'C:/Users/ahmed/Desktop/ahmed folders/progamming/final project/github backend/101_ObjectCategories/'
pickle_file_path = 'C:/Users/ahmed/Desktop/ahmed folders/progamming/final project/github backend/features_caltech101.p'

# %%
import datetime

# %% [markdown]
# ## Create Database 'image2'

# %%
#input_docs(index = 'image3', pickle_path = pickle_file_path)

# %% [markdown]
# ## Test 1 (retrive all data)

# %% [markdown]
# #### Return all images' paths and feature vectors from DB

# %%
tic = datetime.datetime.now()

images , pca_features = get_docs( 'image2' , field = 'features')

tok = datetime.datetime.now()

print( tok - tic )
# Out:
# 0:00:09.261464

# %% [markdown]
# #### Initiate the model

# %%
init_model(images , pca_features,pickle_file_path)
# Out:
# C:\Users\ahmed\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator PCA from version 0.22.2.post1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %% [markdown]
# #### Retrive the most similar images (5 images)

# %% [markdown]
# ##### Note --> you need to change image path

# %%
tic = datetime.datetime.now()

get_similar_images('C:/Users/ahmed/Desktop/ahmed folders/progamming/image_0007.jpg',images_foler_path)

tok = datetime.datetime.now()

print( tok - tic )
# Out:
# 0:00:05.010223

# %%
tic = datetime.datetime.now()

get_similar_images('C:/Users/ahmed/Desktop/ahmed folders/progamming/final project/github backend/101_ObjectCategories/101_ObjectCategories/crocodile/image_0009.jpg',images_foler_path)

tok = datetime.datetime.now()

print( tok - tic )
# Out:
# 0:00:03.332826

# %%
tic = datetime.datetime.now()

get_similar_images('C:/Users/ahmed/Desktop/ahmed folders/progamming/final project/github backend/101_ObjectCategories/101_ObjectCategories/lotus/image_0019.jpg',images_foler_path)

tok = datetime.datetime.now()

print( tok - tic )
# Out:
# 0:00:03.292222

# %% [markdown]
# ## Test 2 (retrive a specific tag)

# %% [markdown]
# #### Return images' paths and feature vectors from DB for Tag = 'ant'

# %%
tic = datetime.datetime.now()

images , pca_features = search_by_tags('image2' , "ant")

tok = datetime.datetime.now()

print( tok - tic )
# Out:
# 0:00:01.030521

# %% [markdown]
# #### Initiate the model & get similar images (top 5 images)

# %%
init_model(images , pca_features,pickle_file_path)

tic = datetime.datetime.now()

get_similar_images('C:/Users/ahmed/Desktop/ahmed folders/progamming/final project/github backend/101_ObjectCategories/101_ObjectCategories/ant/image_0011.jpg',images_foler_path)

tok = datetime.datetime.now()

print( tok - tic )
# Out:
# C:\Users\ahmed\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator PCA from version 0.22.2.post1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# 0:00:05.768292

# %% [markdown]
# ##### Return images' paths and feature vectors from DB for Tag = 'crocodile'

# %%
tic = datetime.datetime.now()

images , pca_features = search_by_tags('image2' , "crocodile")

tok = datetime.datetime.now()

print( tok - tic )
# Out:
# 0:00:00.305677

# %% [markdown]
# #### Initiate the model & get similar images (top 5 images)

# %%
init_model(images , pca_features,pickle_file_path)

tic = datetime.datetime.now()

get_similar_images('C:/Users/ahmed/Desktop/ahmed folders/progamming/final project/github backend/101_ObjectCategories/101_ObjectCategories/crocodile/image_0009.jpg',images_foler_path)

tok = datetime.datetime.now()

print( tok - tic )
# Out:
# C:\Users\ahmed\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator PCA from version 0.22.2.post1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# 0:00:02.112425

# %% [markdown]
# #### Return images' paths and feature vectors from DB for Tag = 'umbrella'

# %%
tic = datetime.datetime.now()

images , pca_features = search_by_tags('image2' , "umbrella")

tok = datetime.datetime.now()

print( tok - tic )
# Out:
# 0:00:00.501421

# %% [markdown]
# #### Initiate the model & get similar images (top 5 images)

# %%
init_model(images , pca_features,pickle_file_path)

tic = datetime.datetime.now()

get_similar_images('C:/Users/ahmed/Desktop/ahmed folders/progamming/final project/github backend/101_ObjectCategories/101_ObjectCategories/umbrella/image_0031.jpg',images_foler_path)

tok = datetime.datetime.now()

print( tok - tic )
# Out:
# C:\Users\ahmed\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator PCA from version 0.22.2.post1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# 0:00:02.108223

# %% [markdown]
# ## Testing 3 (retrive with prediction)

# %% [markdown]
# #### initiate model without images or feature vectors

# %%
images = list()
pca_features = list()
init_model(images , pca_features,pickle_file_path)
# Out:
# C:\Users\ahmed\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator PCA from version 0.22.2.post1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %% [markdown]
# #### predict image tag by vgg16

# %%
prediction = predict_tag("C:/Users/ahmed/Desktop/ahmed folders/progamming/final project/github backend/101_ObjectCategories/101_ObjectCategories/umbrella/image_0031.jpg")
print(prediction)
# Out:
# predicted umbrella with probability 0.999
# predicted parachute with probability 0.000
# predicted mortarboard with probability 0.000
# predicted poncho with probability 0.000
# predicted lampshade with probability 0.000
# umbrella

# %% [markdown]
# #### getting list of images and feature vectors according to specific tag

# %%
tic = datetime.datetime.now()

images , pca_features = search_by_tags('image2' , prediction)

tok = datetime.datetime.now()

print( tok - tic )
# Out:
# 0:00:02.824900

# %% [markdown]
# #### Initiate the model & get similar images (top 5 images)

# %%
init_model(images , pca_features,pickle_file_path)

tic = datetime.datetime.now()

get_similar_images('C:/Users/ahmed/Desktop/ahmed folders/progamming/final project/github backend/101_ObjectCategories/101_ObjectCategories/umbrella/image_0031.jpg',images_foler_path)

tok = datetime.datetime.now()

print( tok - tic )
# Out:
# 0:00:35.051657
